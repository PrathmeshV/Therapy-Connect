# %%
print("🚀 Step 1: Installing required libraries...")
# Out:
# 🚀 Step 1: Installing required libraries...

# %%
# !pip install -q pypdf langchain sentence-transformers chromadb tqdm --quiet
# !pip install -U langchain-community --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 38.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.4 MB/s eta 0:00:00

# %%
print("\nMounting Google Drive...")
from google.colab import drive
drive.mount('/content/drive')
print("✅ Google Drive mounted successfully!")
# Out:
# Mounting Google Drive...
# Mounted at /content/drive
# ✅ Google Drive mounted successfully!

# %%
import os
import chromadb
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import PyPDFLoader
from sentence_transformers import SentenceTransformer
from tqdm import tqdm
import time
import shutil

# %%
DRIVE_PDF_SOURCE_DIR = "/content/drive/MyDrive/RAG"

# %%
DRIVE_PDF_SOURCE_DIR = "/content/drive/MyDrive/RAG"

# ✨ NEW: Path to store the final database directly in Google Drive ✨
DRIVE_CHROMA_DB_PATH = "/content/drive/MyDrive/NEW_RAG"

COLLECTION_NAME = "therapeutic_knowledge_base"
EMBEDDING_MODEL_NAME = "all-MiniLM-L6-v2"
CHUNK_SIZE = 1000
CHUNK_OVERLAP = 150

# %%
print("Configuration set:")
print(f" - PDF Source: {DRIVE_PDF_SOURCE_DIR}")
print(f" - ChromaDB Storage on Drive: {DRIVE_CHROMA_DB_PATH}")
# Out:
# Configuration set:
#  - PDF Source: /content/drive/MyDrive/RAG
#  - ChromaDB Storage on Drive: /content/drive/MyDrive/NEW_RAG

# %%
def load_all_pdfs_from_drive(directory_path):
    documents = []
    print(f"\n🔍 Step 3.1: Searching for PDF files in: {directory_path}")
    if not os.path.exists(directory_path):
        print(f"❌ ERROR: The directory '{directory_path}' was not found.")
        return None
    pdf_files = [f for f in os.listdir(directory_path) if f.endswith('.pdf')]
    if not pdf_files:
        print(f"⚠️ No PDF files found in '{directory_path}'.")
        return None
    print(f"✅ Found {len(pdf_files)} PDF files. Processing...")
    for filename in tqdm(pdf_files, desc="Processing PDFs"):
        try:
            loader = PyPDFLoader(os.path.join(directory_path, filename))
            doc = loader.load()
            documents.extend(doc)
        except Exception as e:
            print(f"\n- Warning for {filename}: pypdf issue detected, but text extraction will proceed.")
    print(f"✅ Loaded {len(documents)} pages from {len(pdf_files)} files.")
    return documents

# %%
def split_documents_into_chunks(documents):
    print("\n🔪 Step 3.2: Chunking documents...")
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=CHUNK_SIZE, chunk_overlap=CHUNK_OVERLAP, length_function=len)
    chunks = text_splitter.split_documents(documents)
    print(f"✅ Successfully created {len(chunks)} text chunks.")
    return chunks

# %%
def build_knowledge_base_on_drive():
    start_time = time.time()
    documents = load_all_pdfs_from_drive(DRIVE_PDF_SOURCE_DIR)
    if not documents:
        print("\nHalting execution: No documents loaded.")
        return
    chunks = split_documents_into_chunks(documents)
    chunk_contents = [chunk.page_content for chunk in chunks]

    print(f"\n🧠 Step 3.3: Loading embedding model: {EMBEDDING_MODEL_NAME}...")
    embedding_model = SentenceTransformer(EMBEDDING_MODEL_NAME, device='cpu')

    print(f"\n💾 Step 3.4: Creating/populating ChromaDB store on Google Drive...")

    # ✨ NEW: Remove old database from Google Drive if it exists ✨
    if os.path.exists(DRIVE_CHROMA_DB_PATH):
        print(f"Found old database. Removing '{DRIVE_CHROMA_DB_PATH}' for a fresh start.")
        shutil.rmtree(DRIVE_CHROMA_DB_PATH)

    # ✨ NEW: Create the client pointing directly to your Drive path ✨
    client = chromadb.PersistentClient(path=DRIVE_CHROMA_DB_PATH)
    collection = client.create_collection(name=COLLECTION_NAME)
    ids = [f"chunk_{i}" for i in range(len(chunks))]

    batch_size = 128
    for i in tqdm(range(0, len(chunks), batch_size), desc="Embedding & Storing"):
        batch_contents = chunk_contents[i:i+batch_size]
        batch_ids = ids[i:i+batch_size]
        batch_embeddings = embedding_model.encode(batch_contents).tolist()
        collection.add(embeddings=batch_embeddings, documents=batch_contents, ids=batch_ids)

    end_time = time.time()
    total_time = end_time - start_time

    print("\n\n🎉 --- Knowledge Base Creation Complete! --- 🎉")
    print(f"Total PDFs processed: {len(os.listdir(DRIVE_PDF_SOURCE_DIR))}")
    print(f"Total text chunks created: {len(chunks)}")
    print(f"✅ Vector store successfully created in your Google Drive at: '{DRIVE_CHROMA_DB_PATH}'")
    print(f"Total time taken: {total_time:.2f} seconds")

# %%
build_knowledge_base_on_drive()
# Out:
# 🔍 Step 3.1: Searching for PDF files in: /content/drive/MyDrive/RAG
# ✅ Found 31 PDF files. Processing...
# Processing PDFs:  48%|████▊     | 15/31 [05:00<05:36, 21.00s/it]WARNING:pypdf._reader:Ignoring wrong pointing object 8 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 22 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 58 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 60 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 62 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 65 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 69 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 74 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 86 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 102 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 232 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 509 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 899 0 (offset 0)
# Processing PDFs:  52%|█████▏    | 16/31 [05:16<04:53, 19.55s/it]WARNING:pypdf._reader:XRef object at 4861 can not be read, some object may be missing
# WARNING:pypdf._reader:Ignoring wrong pointing object 1376 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1377 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1378 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1379 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1380 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1381 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1382 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1383 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1384 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1385 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1386 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1387 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1388 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1389 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1390 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1391 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1392 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1393 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1394 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1395 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1396 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1397 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1398 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1399 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1400 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1401 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1402 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1403 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1404 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1405 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1406 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1407 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1408 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1409 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1410 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1411 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1412 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1413 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1414 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1415 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1416 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1417 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1418 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1419 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1420 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1421 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1422 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1423 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1424 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1425 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1426 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1427 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1428 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1429 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1430 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1431 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1432 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1433 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1434 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1435 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1436 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1437 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1438 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1439 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1440 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1441 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1442 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1443 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1444 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1445 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1446 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1447 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1448 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1449 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1450 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1451 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1452 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1453 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1454 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1455 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1456 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1457 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1458 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1459 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1460 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1461 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1462 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1463 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1464 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1465 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1466 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1467 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1468 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1469 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1470 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1471 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1472 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1473 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1474 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1475 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1476 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1477 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1478 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1479 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1480 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1481 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1482 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1483 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1484 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1485 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1486 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1487 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1488 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1489 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1490 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1491 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1492 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1493 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1494 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1495 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1496 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1497 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1498 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1499 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1500 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1501 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1502 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1503 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1504 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1505 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1506 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 
# Embedding & Storing: 100%|██████████| 323/323 [1:40:46<00:00, 18.72s/it]
# 🎉 --- Knowledge Base Creation Complete! --- 🎉
# Total PDFs processed: 31
# Total text chunks created: 41310
# ✅ Vector store successfully created in your Google Drive at: '/content/drive/MyDrive/NEW_RAG'
# Total time taken: 6729.93 seconds

# %%
print("\n📚 Loading the knowledge base from Drive and the embedding model...")

# Check if the database path exists
if not os.path.exists(DRIVE_CHROMA_DB_PATH):
    raise FileNotFoundError(
        f"Database not found at '{DRIVE_CHROMA_DB_PATH}'. "
        "Please ensure the 'build_knowledge_base' script ran successfully."
    )
# Out:
# 📚 Loading the knowledge base from Drive and the embedding model...

# %%
client = chromadb.PersistentClient(path=DRIVE_CHROMA_DB_PATH)
collection = client.get_collection(name=COLLECTION_NAME)

# %%
embedding_model = SentenceTransformer(EMBEDDING_MODEL_NAME, device='cpu')
print("✅ Knowledge base and model loaded successfully!")
# Out:
# ✅ Knowledge base and model loaded successfully!

# %%
def search_knowledge_base(query_text, n_results=5):
    """
    Searches the vector database for text chunks related to a query.
    """
    query_embedding = embedding_model.encode(query_text).tolist()
    results = collection.query(
        query_embeddings=[query_embedding],
        n_results=n_results
    )
    return results['documents'][0]

# %%
simulated_classifier_output = [
    ('sadness', 0.85),
    ('anxiety', 0.62),
    ('loneliness', 0.45)
]
print(f"\nReceived classifier output: {simulated_classifier_output}")
# Out:
# Received classifier output: [('sadness', 0.85), ('anxiety', 0.62), ('loneliness', 0.45)]

# %%
def create_query_from_emotions(emotion_data, score_threshold=0.5):
    """
    Translates a list of emotions and scores into a natural language query.
    """
    if not emotion_data:
        return "General advice for mental well-being."
    primary_emotion = emotion_data[0][0]
    secondary_emotions = [
        emotion[0] for emotion in emotion_data[1:]
        if emotion[1] > score_threshold
    ]
    query = f"What are some therapeutic techniques, coping mechanisms, and advice for someone experiencing strong feelings of {primary_emotion}?"
    if secondary_emotions:
        secondary_str = " and ".join(secondary_emotions)
        query += f" They may also be feeling {secondary_str}."
    return query

# %%
def retrieve_context(classifier_output, n_results=5):
    """
    Orchestrates the retrieval process.
    """
    search_query = create_query_from_emotions(classifier_output)
    print(f"\n🧠 Translated into search query: '{search_query}'")

    print(f"\n🔍 Searching knowledge base...")
    retrieved_docs = search_knowledge_base(search_query, n_results)

    return retrieved_docs

# %%
# --- EXECUTION ---
retrieved_context = retrieve_context(simulated_classifier_output)

# 5. DISPLAY RESULTS
print("\n✅ Retrieval complete! Here is the context we found:\n")
for i, doc in enumerate(retrieved_context):
    print(f"--- Context Chunk {i+1} ---\n")
    print(doc)
    print("\n" + "="*50 + "\n")
# Out:
# 🧠 Translated into search query: 'What are some therapeutic techniques, coping mechanisms, and advice for someone experiencing strong feelings of sadness? They may also be feeling anxiety.'
#
# 🔍 Searching knowledge base...
#
# ✅ Retrieval complete! Here is the context we found:
#
# --- Context Chunk 1 ---
#
# III: Conditions & Issues: Loss & Bereavement
# 89
#
# Counseling Interventions
#
# Individuals will vary in the way and degree to which they
# grieve.  People with prolonged distress or distress affecting
# their function should be evaluated for major depression and
# other psychological conditions.
#
# The following general points may be useful in helping people
# through the grieving process:
#
# 1. Ensure that normal culturally appropriate mourning proc-
# esses have been able to take place.
# 2. Provide reassurance that the grieving process is normal de-
# spite the painful feelings it causes.  Do not force talking.  Peo-
# ple choose their own times and situations to share feelings –
# but make it clear that you can listen if they wish to share their
# painful experiences and feelings.
# 3. Encourage finding simple ways to enjoy positive memories
# of the past (e.g. through photographs and stories).
# 4. Provide reassurance that unbearable, painful feelings can
# decrease over time.
#
# ==================================================
#
# --- Context Chunk 2 ---
#
# depression to recognize and deal with their excessive guilt, shame, humiliation, anger and other
# painful feelings. They help the depressed individual understand the impact that depression has had
# on their personality development and relationships.
# Some depressed people are very sensitive to slights, disappointments in others injuries to their self
# esteem and have become overly prone to humiliation and anger as a result. Psychoanalysts can help
# them understand the early experiences that led to these sensitivities and assist them in developing
# a more resilient sense of self. Additionally, troubling early relationships may sometimes lead to
# lifelong feelings of inner deadness, sadness, disconnectedness or emptiness that can coalesce into a
# later life depression. Psychoanalytic understanding often helps the person with depression avoid
# the vicious emotional cycles that can cause or contribute depressive episodes.
# Eating Disorders
#
# ==================================================
#
# --- Context Chunk 3 ---
#
# ing, depression, and acceptance, have been described by Kubler-Ross and
# are outlined in detail in the chapter on “Loss & Bereavement.”  These
# emotions are not necessarily experienced by patients in a particular se-
# quence and caregivers may also experience these reactions.  Helping both
# patients and caregivers accept the limitations on what they can do or con-
# trol within the situation is important.  Helping individuals identify and
# focus on the positives and reframe negative thoughts can be useful.  Pa-
# tients and caregivers should be encouraged to identify and actively incor-
# porate into their lives those things that give them pleasure.
#
# ==================================================
#
# --- Context Chunk 4 ---
#
# point of view.
# Anxiety Avoiding threat. Seeking Concern Facing up to threats.
# excessive reassurance. Seeking a reasonable
# amount of reassurance.
# Depression Withdrawing from social Sadness After a period of mourning
# reinforcements and and reflection, reinvesting in
# meaningful or enjoyed the company of others.
# activities. Self-isolating. Carrying on with meaningful
# or enjoyed activities.
# Acidic envy Spoiling another’s enjoy- Benign envy Striving to gain what
# ment of what you want another has that you desire
# but don’t have. Sour but don’t have. Allowing
# grapes. Pretending you others to enjoy what they
# don’t really want what have without trying to spoil it
# they have. for them. Admitting that you
# want what they have.
# Guilt Begging forgiveness from Remorse Asking for forgiveness and
# or avoiding facing the facing up to the person you
# person you have wronged. have wronged. Taking the
# Taking too much correct amount of
# responsibility for the responsibility for the
#
# ==================================================
#
# --- Context Chunk 5 ---
#
# The Process of Grieving
# Typical grief reactions involve emotional, mental, physical, and social responses. These reactions can include feelings
# of numbness, anger, guilt, anxiety, sadness, and despair. The individual can experience difficulty concentrating, sleep
# 416 | Death, Dying, & Bereavement
#
# ==================================================

# %%
# ==============================================================================
# PHASE 3: THE GENERATION ENGINE (Using Gemini 1.5 Pro)
# ==============================================================================
import google.generativeai as genai
from google.colab import userdata
import warnings

warnings.filterwarnings("ignore", category=UserWarning, module="sentence_transformers")
print("🚀 Initializing the Generation Engine...")

# ------------------------------------------------------------------------------
# 1. CONFIGURE THE GEMINI LLM
# ------------------------------------------------------------------------------
try:
    GEMINI_API_KEY = userdata.get('GEMINI_API_KEY')
    genai.configure(api_key=GEMINI_API_KEY)
    model = genai.GenerativeModel('gemini-2.5-pro')
    print("✅ Gemini 1.5 Pro model configured successfully!")
except Exception as e:
    print(f"❌ Error configuring Gemini: {e}")
    print("Please make sure you have set up your GEMINI_API_KEY in Colab Secrets.")
    model = None

# ------------------------------------------------------------------------------
# 2. GATHER ALL OUR INPUT DATA
#    We'll use the simulated/retrieved data from our previous steps.
# ------------------------------------------------------------------------------
original_text = "I messed up the presentation I've been working on for weeks. My boss was not happy. I just feel like a total failure right now."

simulated_classifier_output = [
    ('failure', 0.90),
    ('disappointment', 0.75),
    ('anxiety', 0.55)
]

# (For a real run, you'd call retrieve_context() here. We'll use a sample for this example.)
retrieved_context_str = """
- From "Mindset" (Carol S. Dweck): "Even in the growth mindset, failure can be a painful experience. But it doesn't define you. It's a problem to be faced, dealt with, and learned from."
- From "Cognitive Behavioural Therapy Workbook": "Challenging Automatic Thoughts: When you have a thought like 'I'm a total failure,' that is an automatic negative thought (ANT). The first step is to recognize it. The second is to question it."
- From "Acceptance and Commitment Therapy": "The goal is not to eliminate feelings of failure, but to make room for them. This is called acceptance. You can acknowledge the feeling without letting it dictate your actions."
"""

# ------------------------------------------------------------------------------
# 3. STEP A: GENERATE CLARIFYING QUESTIONS
# ------------------------------------------------------------------------------

# This is a carefully crafted "meta-prompt" that tells the LLM how to behave.
prompt_for_questions = f"""
You are an empathetic therapeutic assistant. Your goal is to help the user reflect on their situation.
You have been given the following information about a user:

1.  **Original User Text:** "{original_text}"
2.  **Detected Emotions:** {simulated_classifier_output}
3.  **Relevant Therapeutic Concepts:** "{retrieved_context_str}"

Your first task is to ask the user 5 clarifying questions to better understand their situation. Do NOT offer any advice or solutions yet.
The questions must be either Yes/No or on a gradient scale (e.g., "On a scale of 1 to 5...").

The goal of these questions is to help you understand the user's immediate state and their thought patterns.

Return ONLY a numbered list of the 5 questions and nothing else.
"""

print("\n🤖 Generating clarifying questions from the LLM...")
if model:
    try:
        response_questions = model.generate_content(prompt_for_questions)
        clarifying_questions = response_questions.text
        print("\n--- LLM Generated Questions ---")
        print(clarifying_questions)

        # ------------------------------------------------------------------------------
        # 4. SIMULATE USER ANSWERS
        #    In a real app, you would pause here and get input from the user.
        # ------------------------------------------------------------------------------
        simulated_user_answers = """
        1. Yes
        2. 5
        3. Yes
        4. No
        5. 2
        """
        print("\n--- User's Answers (Simulated) ---")
        print(simulated_user_answers)

        # ------------------------------------------------------------------------------
        # 5. STEP B: GENERATE THE FINAL RESPONSE
        # ------------------------------------------------------------------------------
        prompt_for_final_response = f"""
        You are an empathetic therapeutic assistant. You have all the initial information about the user, and they have now answered your clarifying questions.

        **Initial Information:**
        - User Text: "{original_text}"
        - Detected Emotions: {simulated_classifier_output}
        - Relevant Concepts: "{retrieved_context_str}"

        **Your Questions and the User's Answers:**
        - Your Questions: "{clarifying_questions}"
        - User's Answers: "{simulated_user_answers}"

        Your final task is to synthesize ALL of this information into a single, supportive, and actionable paragraph.
        In your response, you must:
        1. Acknowledge the user's feelings and their answers.
        2. Integrate the most relevant insight from the retrieved therapeutic concepts.
        3. Offer one gentle, actionable suggestion or a reflective prompt based on these concepts.
        4. Maintain a supportive and non-judgmental tone.

        Your entire response must be a single paragraph of 300 to 500 words.
        """

        print("\n🤖 Generating final response from the LLM...")
        response_final = model.generate_content(prompt_for_final_response)
        final_paragraph = response_final.text
        print("\n\n--- FINAL THERAPEUTIC RESPONSE ---")
        print(final_paragraph)

    except Exception as e:
        print(f"❌ An error occurred during LLM generation: {e}")
# Out:
# 🚀 Initializing the Generation Engine...
# ✅ Gemini 1.5 Pro model configured successfully!
#
# 🤖 Generating clarifying questions from the LLM...
#
# --- LLM Generated Questions ---
# 1. On a scale of 1 to 5 (where 5 is 'completely'), how much do you believe the thought "I'm a total failure"?
# 2. On a scale of 1 to 5 (where 5 is 'overwhelming'), how intense is this feeling for you at this very moment?
# 3. Does it feel like this one event defines your entire worth right now?
# 4. Is this feeling about the presentation casting a shadow over other, unrelated areas of your life as well?
# 5. Before you received your boss's feedback, was there any part of the work you did that you felt proud of?
#
# --- User's Answers (Simulated) ---
#
#         1. Yes
#         2. 5
#         3. Yes
#         4. No
#         5. 2
#
#
# 🤖 Generating final response from the LLM...
#
#
# --- FINAL THERAPEUTIC RESPONSE ---
# Thank you for sharing that with me. It makes complete sense that this feeling of failure is so overwhelming for you right now, a 5 out of 5 in intensity. It’s incredibly painful when one single event, especially after weeks of hard work, feels like it defines your entire worth, and I hear how completely you believe that thought "I'm a total failure" at this moment. This kind of thought is what therapists often call an "automatic negative thought"—it can feel like an undeniable truth, especially when it’s tied to such a potent and disappointing experience with your boss. However, it's also important to hold space for what experts on mindset have discovered: even when failure feels this agonizing, it is an experience, not a permanent identity. It is a problem to be faced, dealt with, and learned from, but it does not have the final say on who you are. I was struck by your answer that this feeling, while incredibly intense, is not casting a shadow over other unrelated areas of your life. That is a significant observation and a quiet testament to your resilience, showing that a part of you already knows that you are more than this one presentation, even if it's hard to feel that right now. This brings me to the other crucial piece of information you shared: that before the feedback, there was a part of your work you felt some pride in, even if it was just a 2 out of 5. The current pain doesn't erase that fact. As a gentle next step, I invite you to consider this reflective prompt without any pressure: when you feel you can, try to gently bring to mind that "2 out of 5" feeling. Don't try to fight the feeling of failure, but simply see if you can make a little room for this other, smaller truth to exist alongside it. What was it about that specific part of the work that earned that '2' from you? Simply acknowledging that this flicker of pride was real is a powerful first step in challenging the all-or-nothing belief that you are a "total failure" and seeing this as the complex, painful, and ultimately survivable event that it is.
